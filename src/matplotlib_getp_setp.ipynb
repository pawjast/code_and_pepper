# %% [markdown]
# # `matplotlib` using `.setp` and `.getp`

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager

# Add system fonts so matplotlib sees them
for font in font_manager.findSystemFonts(fontpaths=None, fontext='ttf'):
    font_manager.fontManager.addfont(font)

# %%
# DEV
from datetime import date

metadata_dict = {
    "Title": "Twitter/X Matplotlib tutorial",
    "Author": "Pawel Jastrzebski (pawjast)",
    "Description": "https://medium.com/@pawjast https://twitter.com/pawjast https://github.com/pawjast www.linkedin.com/in/pawjast https://www.youtube.com/@pawjast https://pawjast.substack.com/",
    "Creation Time": f"{date.today():%d %B %Y}",
    "Source": "https://twitter.com/pawjast"
}

# %% [markdown]
# ## Data

# %%
x = [6, 2, 5, 3, 4, -10]

# %% [markdown]
# ## Plot

# %%
plt.rcParams.update(
    {
        "font.family": "Roboto",
        "font.size": 22,
        "hatch.linewidth": 1.75,
    }
)

# %%
fig, ax = plt.subplots(
    figsize=(16,12),
    facecolor="white",
    layout="constrained"
)
fig.suptitle(
    "My motivation throughout the day",
    fontsize=25,
    weight="bold"
)

line, = ax.plot(
    x,
    label="Data"
)

lgd = ax.legend()
ax.grid()


# Footer
ax.text(
    1, -0.08,
    "by @pawjast\nmade with @matplotlib \u2665",
    transform = ax.transAxes,
    horizontalalignment="right",
    verticalalignment="bottom",
    color="#9a9996",
    fontsize=16,
    family="monospace",
    weight="medium"
)

# plt.savefig(
#     fname="name.png",
#     format="png",
#     dpi=125,
#     metadata=metadata_dict
# );
# Out:
# Text(1, -0.08, 'by @pawjast\nmade with @matplotlib ♥')

# %% [markdown]
# ## Look up properties

# %%
plt.getp(fig)
# Out:
#     agg_filter = None
#     alpha = None
#     animated = False
#     axes = [<Axes: >]
#     children = [<matplotlib.patches.Rectangle object at 0x000001C...
#     clip_box = None
#     clip_on = True
#     clip_path = None
#     constrained_layout = True
#     constrained_layout_pads = (0.04167, 0.04167, 0.02, 0.02)
#     default_bbox_extra_artists = [<Axes: >, Text(0.5, 0.9965275, 'My motivation thr...
#     dpi = 100.0
#     edgecolor = (1.0, 1.0, 1.0, 1.0)
#     facecolor = (1.0, 1.0, 1.0, 1.0)
#     figheight = 12.0
#     figure = Figure(1600x1200)
#     figwidth = 16.0
#     frameon = True
#     gid = None
#     in_layout = True
#     label =
#     layout_engine = <matplotlib.layout_engine.ConstrainedLayoutEngine ...
#     linewidth = 0.0
#     mouseover = False
#     path_effects = []
#     picker = None
#     rasterized = False
#     size_inches = [16. 12.]
#     sketch_params = None
#     snap = None
#     suptitle = My motivation throughout the day
#     supxlabel =
#     supylabel =
#     tight_layout = False
#     tightbbox = TransformedBbox(     Bbox(x0=4.1669999999999945, y...
#     transform = IdentityTransform()
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     visible = True
#     window_extent = TransformedBbox(     Bbox(x0=0.0, y0=0.0, x1=16.0,...
#     zorder = 0

# %%
plt.getp(ax)
# Out:
#     adjustable = box
#     agg_filter = None
#     alpha = None
#     anchor = C
#     animated = False
#     aspect = auto
#     autoscale_on = True
#     autoscalex_on = True
#     autoscaley_on = True
#     axes_locator = None
#     axisbelow = line
#     box_aspect = None
#     children = [<matplotlib.lines.Line2D object at 0x000001CA49AF...
#     clip_box = None
#     clip_on = True
#     clip_path = None
#     data_ratio = 3.2
#     default_bbox_extra_artists = [Text(1, -0.08, 'by @pawjast\nmade with @matplotli...
#     facecolor or fc = (1.0, 1.0, 1.0, 1.0)
#     figure = Figure(1600x1200)
#     frame_on = True
#     gid = None
#     gridspec = GridSpec(1, 1)
#     images = <a list of 0 AxesImage objects>
#     in_layout = True
#     label =
#     legend = Legend
#     legend_handles_labels = ([<matplotlib.lines.Line2D object at 0x000001CA49A...
#     lines = <a list of 1 Line2D objects>
#     mouseover = False
#     navigate = True
#     navigate_mode = None
#     path_effects = []
#     picker = None
#     position = Bbox(x0=0.040946388888888886, y0=0.074485465120000...
#     rasterization_zorder = None
#     rasterized = False
#     shared_x_axes = <matplotlib.cbook.GrouperView object at 0x000001CA...
#     shared_y_axes = <matplotlib.cbook.GrouperView object at 0x000001CA...
#     sketch_params = None
#     snap = None
#     subplotspec = GridSpec(1, 1)[0:1, 0:1]
#     tightbbox = Bbox(x0=4.1669999999999945, y0=4.173242795520039, ...
#     title =
#     transform = IdentityTransform()
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     visible = True
#     window_extent = TransformedBbox(     Bbox(x0=0.040946388888888886,...
#     xaxis = XAxis(65.51422222222222,89.38255814400001)
#     xaxis_transform = BlendedGenericTransform(     CompositeGenericTrans...
#     xbound = (-0.25, 5.25)
#     xgridlines = <a list of 8 Line2D gridline objects>
#     xlabel =
#     xlim = (-0.25, 5.25)
#     xmajorticklabels = [Text(-1.0, 0, '−1'), Text(0.0, 0, '0'), Text(1.0,...
#     xminorticklabels = []
#     xscale = linear
#     xticklabels = [Text(-1.0, 0, '−1'), Text(0.0, 0, '0'), Text(1.0,...
#     xticklines = <a list of 16 Line2D ticklines objects>
#     xticks = [-1.  0.  1.  2.  3.  4.]...
#     yaxis = YAxis(65.51422222222222,89.38255814400001)
#     yaxis_transform = BlendedGenericTransform(     BboxTransformTo(     ...
#     ybound = (-10.8, 6.8)
#     ygridlines = <a list of 11 Line2D gridline objects>
#     ylabel =
#     ylim = (-10.8, 6.8)
#     ymajorticklabels = [Text(0, -12.0, '−12'), Text(0, -10.0, '−10'), Tex...
#     yminorticklabels = []
#     yscale = linear
#     yticklabels = [Text(0, -12.0, '−12'), Text(0, -10.0, '−10'), Tex...
#     yticklines = <a list of 22 Line2D ticklines objects>
#     yticks = [-12. -10.  -8.  -6.  -4.  -2.]...
#     zorder = 0

# %%
plt.getp(line)
# Out:
#     agg_filter = None
#     alpha = None
#     animated = False
#     antialiased or aa = True
#     bbox = Bbox(x0=0.0, y0=-10.0, x1=5.0, y1=6.0)
#     children = []
#     clip_box = TransformedBbox(     Bbox(x0=0.0, y0=0.0, x1=1.0, ...
#     clip_on = True
#     clip_path = None
#     color or c = #1f77b4
#     dash_capstyle = butt
#     dash_joinstyle = round
#     data = (array([0., 1., 2., 3., 4., 5.]), array([  6,   2,...
#     drawstyle or ds = default
#     figure = Figure(1600x1200)
#     fillstyle = full
#     gapcolor = None
#     gid = None
#     in_layout = True
#     label = Data
#     linestyle or ls = -
#     linewidth or lw = 1.5
#     marker = None
#     markeredgecolor or mec = #1f77b4
#     markeredgewidth or mew = 1.0
#     markerfacecolor or mfc = #1f77b4
#     markerfacecoloralt or mfcalt = none
#     markersize or ms = 6.0
#     markevery = None
#     mouseover = False
#     path = Path(array([[  0.,   6.],        [  1.,   2.],    ...
#     path_effects = []
#     picker = None
#     pickradius = 5
#     rasterized = False
#     sketch_params = None
#     snap = None
#     solid_capstyle = projecting
#     solid_joinstyle = round
#     tightbbox = Bbox(x0=135.07416666666666, y0=137.79694186472727,...
#     transform = CompositeGenericTransform(     TransformWrapper(  ...
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     visible = True
#     window_extent = Bbox(x0=135.07416666666666, y0=137.79694186472727,...
#     xdata = [0. 1. 2. 3. 4. 5.]
#     xydata = [[  0.   6.]  [  1.   2.]  [  2.   5.]  [  3.   3....
#     ydata = [  6   2   5   3   4 -10]
#     zorder = 2

# %%
plt.getp(lgd)
# Out:
#     agg_filter = None
#     alignment = center
#     alpha = None
#     animated = False
#     bbox_to_anchor = TransformedBbox(     Bbox(x0=0.040946388888888886,...
#     children = [<matplotlib.offsetbox.VPacker object at 0x000001C...
#     clip_box = None
#     clip_on = True
#     clip_path = None
#     default_handler_map = {<class 'matplotlib.container.StemContainer'>: <ma...
#     draggable = False
#     figure = Figure(1600x1200)
#     frame = FancyBboxPatch((1413.26, 1091.6), width=173.125, h...
#     frame_on = True
#     gid = None
#     in_layout = True
#     label =
#     legend_handler_map = {<class 'matplotlib.container.StemContainer'>: <ma...
#     lines = [<matplotlib.lines.Line2D object at 0x000001CA49AF...
#     mouseover = False
#     patches = <a list of 0 Patch objects>
#     path_effects = []
#     picker = None
#     rasterized = False
#     sketch_params = None
#     snap = None
#     texts = <a list of 1 Text objects>
#     tightbbox = Bbox(x0=1407.4302222222223, y0=1085.7767777777774,...
#     title = Text(0, 0, '')
#     transform = IdentityTransform()
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     visible = True
#     window_extent = Bbox(x0=1407.4302222222223, y0=1085.7767777777774,...
#     zorder = 5

# %% [markdown]
# ## Set up new properties

# %%
plt.setp(
    fig,
    facecolor="azure"
)

plt.setp(
    ax,
    frame_on=False,
    ylim = (-12, 12)
)

plt.setp(
    line,
    linestyle="dashed",
    linewidth=4,
    color="dodgerblue"
)

plt.setp(
    lgd,
    title="The legend",
)
# Out:
# [None]

# %%
fig
